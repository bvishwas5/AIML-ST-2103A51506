# %% [markdown]
# <a href="https://colab.research.google.com/github/bvishwas5/AIML-ST-2103A51506/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

data = np.array([
    [0.1, 0.2],
    [0.2, 0.3],
    [0.3, 0.4],
    [-1, -2],
    [-3, -4],
    [-4, -5]
])

kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(data)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

for i, point in enumerate(data):
    print(f"Point {point} is in Cluster {labels[i]}")

plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', marker='o')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=200, label='Centroids')
plt.title("K-Means Clustering")
plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Point [0.1 0.2] is in Cluster 0
# Point [0.2 0.3] is in Cluster 0
# Point [0.3 0.4] is in Cluster 0
# Point [-1. -2.] is in Cluster 0
# Point [-3. -4.] is in Cluster 1
# Point [-4. -5.] is in Cluster 1
