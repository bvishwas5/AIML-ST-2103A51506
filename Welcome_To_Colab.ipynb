# %% [markdown]
# <a href="https://colab.research.google.com/github/bvishwas5/AIML-ST-2103A51506/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!
#
# ## Explore the Gemini API
# The Gemini API gives you access to Gemini models created by Google DeepMind. Gemini models are built from the ground up to be multimodal, so you can reason seamlessly across text, images, code, and audio.
#
# **How to get started?**
# *  Go to [Google AI Studio](https://aistudio.google.com/) and log in with your Google account.
# *  [Create an API key](https://aistudio.google.com/app/apikey).
# * Use a quickstart for [Python](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started.ipynb), or call the REST API using [curl](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/rest/Prompting_REST.ipynb).
#
# **Discover Gemini's advanced capabilities**
# *  Play with Gemini [multimodal outputs](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Image-out.ipynb), mixing text and images in an iterative way.
# *  Discover the [multimodal Live API](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_LiveAPI.ipynb ) (demo [here](https://aistudio.google.com/live)).
# *  Learn how to [analyze images and detect items in your pictures](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Spatial_understanding.ipynb") using Gemini (bonus, there's a [3D version](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Spatial_understanding_3d.ipynb) as well!).
# *  Unlock the power of [Gemini thinking model](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/quickstarts/Get_started_thinking.ipynb), capable of solving complex task with its inner thoughts.
#
# **Explore complex use cases**
# *  Use [Gemini grounding capabilities](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Search_grounding_for_research_report.ipynb) to create a report on a company based on what the model can find on internet.
# *  Extract [invoices and form data from PDF](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Pdf_structured_outputs_on_invoices_and_forms.ipynb) in a structured way.
# *  Create [illustrations based on a whole book](https://colab.research.google.com/github/google-gemini/cookbook/blob/main/examples/Book_illustration.ipynb) using Gemini large context window and Imagen.
#
# To learn more, check out the [Gemini cookbook](https://github.com/google-gemini/cookbook) or visit the [Gemini API documentation](https://ai.google.dev/docs/).

# %% [markdown]
# Colab now has AI features powered by [Gemini](https://gemini.google.com). The video below provides information on how to use these features, whether you're new to Python, or a seasoned veteran.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=V7RXyqFUR98" target="_blank">
#   <img alt='Thumbnail for a video showing 3 AI-powered Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or "Colaboratory", allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) or [Colab Features You May Have Missed](https://www.youtube.com/watch?v=rNgswRZ2C1Y) to learn more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## **Getting started**
# </div>
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.
#
# For example, if you find yourself waiting for **pandas** code to finish running and want to go faster, you can switch to a GPU Runtime and use libraries like [RAPIDS cuDF](https://rapids.ai/cudf-pandas) that provide zero-code-change acceleration.

# %% [markdown]
# To learn more about accelerating pandas on Colab, see the [10 minute guide](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_colab_demo.ipynb) or
#  [US stock market data analysis demo](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cudf_pandas_stocks_demo.ipynb).

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb).

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More Resources
#
# ### Working with Notebooks in Colab
#
# </div>
#
# - [Overview of Colab](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with Data
# </div>
#
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Intro to RAPIDS cuDF to accelerate pandas](https://nvda.ws/rapids-cudf)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TPUs in Colab](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
import random
import math as mt
x=random.uniform(-10, 10)
eta=0.01
max_iter=10000 # Corrected typo: 'nax_iter' to 'max_iter'

def gradient (x):
    return 2*x

for iter in range(max_iter):
    del_x=-eta*gradient(x)
    x=x+del_x
    print('optimal point is =', x) # Indented to be inside the loop
    print('objective function =',mt.pow(x,2)+5) # Indented, corrected syntax
# Out:
# optimal point is = 9.285431214548897
# objective function = 91.219232840119
# optimal point is = 9.099722590257919
# objective function = 87.80495121965029
# optimal point is = 8.91772813845276
# objective function = 84.52587515135214
# optimal point is = 8.739373575683706
# objective function = 81.3766504953586
# optimal point is = 8.564586104170031
# objective function = 78.35213513574239
# optimal point is = 8.39329438208663
# objective function = 75.44739058436699
# optimal point is = 8.225428494444897
# objective function = 72.65767391722603
# optimal point is = 8.060919924555998
# objective function = 69.97843003010388
# optimal point is = 7.899701526064878
# objective function = 67.40528420091177
# optimal point is = 7.74170749554358
# objective function = 64.93403494655566
# optimal point is = 7.586873345632709
# objective function = 62.560647162672055
# optimal point is = 7.435135878720055
# objective function = 60.281245535030244
# optimal point is = 7.286433161145654
# objective function = 58.09210821184305
# optimal point is = 7.140704497922741
# objective function = 55.98966072665406
# optimal point is = 6.997890407964286
# objective function = 53.970470161878566
# optimal point is = 6.857932599805
# objective function = 52.03123954346817
# optimal point is = 6.7207739478089
# objective function = 50.16880245754683
# optimal point is = 6.586358468852723
# objective function = 48.38011788022798
# optimal point is = 6.454631299475668
# objective function = 46.66226521217095
# optimal point is = 6.325538673486155
# objective function = 45.01243950976898
# optimal point is = 6.199027900016431
# objective function = 43.427946905182125
# optimal point is = 6.075047342016102
# objective function = 41.90620020773691
# optimal point is = 5.95354639517578
# objective function = 40.444714679510525
# optimal point is = 5.834475467272265
# objective function = 39.04110397820191
# optimal point is = 5.71778595792682
# objective function = 37.69307626066512
# optimal point is = 5.603430238768284
# objective function = 36.398430440742786
# optimal point is = 5.491361633992918
# objective function = 35.155052595289376
# optimal point is = 5.3815344013130595
# objective function = 33.96091251251591
# optimal point is = 5.273903713286798
# objective function = 32.81406037702028
# optimal point is = 5.168425639021063
# objective function = 31.71262358609028
# optimal point is = 5.065057126240641
# objective function = 30.654803692081106
# optimal point is = 4.963755983715829
# objective function = 29.638873465874696
# optimal point is = 4.8644808640415125
# objective function = 28.66317407662606
# optimal point is = 4.7671912467606825
# objective function = 27.72611238319167
# optimal point is = 4.671847421825468
# objective function = 26.826158332817275
# optimal point is = 4.578410473388959
# objective function = 25.961842462837712
# optimal point is = 4.48684226392118
# objective function = 25.13175350130934
# optimal point is = 4.397105418642757
# objective function = 24.33453606265749
# optimal point is = 4.309163310269901
# objective function = 23.56888843457625
# optimal point is = 4.222980044064503
# objective function = 22.83356045256703
# optimal point is = 4.1385204431832125
# objective function = 22.127351458645375
# optimal point is = 4.055750034319549
# objective function = 21.449108340883022
# optimal point is = 3.9746350336331577
# objective function = 20.797723650584054
# optimal point is = 3.8951423329604946
# objective function = 20.172133794020922
# optimal point is = 3.817239486301285
# objective function = 19.571317295777696
# optimal point is = 3.740894696575259
# objective function = 18.9942931308649
# optimal point is = 3.666076802643754
# objective function = 18.44011912288265
# optimal point is = 3.592755266590879
# objective function = 17.9078904056165
# optimal point is = 3.5209001612590614
# objective function = 17.396737945554086
# optimal point is = 3.4504821580338803
# objective function = 16.905827122910143
# optimal point is = 3.3814725148732028
# objective function = 16.434356368842902
# optimal point is = 3.313843064575739
# objective function = 15.981555856636724
# optimal point is = 3.247566203284224
# objective function = 15.54668624471391
# optimal point is = 3.18261487921854
# objective function = 15.12903746942324
# optimal point is = 3.118962581634169
# objective function = 14.727927585634081
# optimal point is = 3.0565833300014855
# objective function = 14.34270165324297
# optimal point is = 2.9954516634014556
# objective function = 13.972730667774547
# optimal point is = 2.9355426301334266
# objective function = 13.617410533330677
# optimal point is = 2.876831777530758
# objective function = 13.276161076210782
# optimal point is = 2.819295141980143
# objective function = 12.948425097592835
# optimal point is = 2.7629092391405403
# objective function = 12.633667463728159
# optimal point is = 2.7076510543577297
# objective function = 12.331374232164524
# optimal point is = 2.653498033270575
# objective function = 12.04105181257081
# optimal point is = 2.6004280726051636
# objective function = 11.762226160793006
# optimal point is = 2.5484195111530603
# objective function = 11.494442004825604
# optimal point is = 2.497451120929999
# objective function = 11.23726210143451
# optimal point is = 2.447502098511399
# objective function = 10.990266522217702
# optimal point is = 2.3985520565411713
# objective function = 10.753051967937882
# optimal point is = 2.3505810154103477
# objective function = 10.525231110007542
# optimal point is = 2.3035693951021408
# objective function = 10.306431958051242
# optimal point is = 2.257498007200098
# objective function = 10.096297252512414
# optimal point is = 2.212348047056096
# objective function = 9.894483881312922
# optimal point is = 2.168101086114974
# objective function = 9.70066231961293
# optimal point is = 2.1247390643926742
# objective function = 9.514516091756256
# optimal point is = 2.0822442831048207
# objective function = 9.33574125452271
# optimal point is = 2.0405993974427243
# objective function = 9.16404590084361
# optimal point is = 1.99978740949387
# objective function = 8.999149683170202
# optimal point is = 1.9597916613039925
# objective function = 8.840783355716663
# optimal point is = 1.9205958280779127
# objective function = 8.688688334830283
# optimal point is = 1.8821839115163546
# objective function = 8.542616276771005
# optimal point is = 1.8445402332860275
# objective function = 8.402328672210873
# optimal point is = 1.8076494286203069
# objective function = 8.267596456791322
# optimal point is = 1.7714964400479007
# objective function = 8.138199637102385
# optimal point is = 1.7360665112469427
# objective function = 8.013926931473131
# optimal point is = 1.7013451810220037
# objective function = 7.894575424986795
# optimal point is = 1.6673182774015636
# objective function = 7.779950238157317
# optimal point is = 1.6339719118535323
# objective function = 7.669864208726287
# optimal point is = 1.6012924736164615
# objective function = 7.564137586060726
# optimal point is = 1.5692666241441322
# objective function = 7.462597737652722
# optimal point is = 1.5378812916612496
# objective function = 7.365078867241674
# optimal point is = 1.5071236658280247
# objective function = 7.2714217440989035
# optimal point is = 1.4769811925114642
# objective function = 7.181473443032587
# optimal point is = 1.447441568661235
# objective function = 7.0950870946884965
# optimal point is = 1.4184927372880103
# objective function = 7.012121645738832
# optimal point is = 1.39012288254225
# objective function = 6.932441628567574
# optimal point is = 1.362320424891405
# objective function = 6.855916940076298
# optimal point is = 1.3350740163935768
# objective function = 6.782422629249277
# optimal point is = 1.3083725360657052
# objective function = 6.711838693131005
# optimal point is = 1.2822050853443911
# objective function = 6.644049880883017
# optimal point is = 1.2565609836375033
# objective function = 6.57894550560005
# optimal point is = 1.2314297639647533
# objective function = 6.516419263578288
# optimal point is = 1.2068011686854583
# objective function = 6.456369060740588
# optimal point is = 1.1826651453117492
# objective function = 6.398696845935261
# optimal point is = 1.1590118424055142
# objective function = 6.343308450836225
# optimal point is = 1.135831605557404
# objective function = 6.290113436183111
# optimal point is = 1.113114973446256
# objective function = 6.239024944110259
# optimal point is = 1.0908526739773308
# objective function = 6.189959556323492
# optimal point is = 1.0690356204977842
# objective function = 6.142837157893083
# optimal point is = 1.0476549080878286
# objective function = 6.097580806440517
# optimal point is = 1.026701809926072
# objective function = 6.054116606505472
# optimal point is = 1.0061677737275507
# objective function = 6.012373588887856
# optimal point is = 0.9860444182529997
# objective function = 5.972283594767896
# optimal point is = 0.9663235298879397
# objective function = 5.9337811644150875
# optimal point is = 0.9469970592901809
# objective function = 5.89680343030425
# optimal point is = 0.9280571181043772
# objective function = 5.861290014464202
# optimal point is = 0.9094959757422897
# objective function = 5.8271829298914195
# optimal point is = 0.8913060562274439
# objective function = 5.794426485867719
# optimal point is = 0.873479935102895
# objective function = 5.762967197027358
# optimal point is = 0.8560103364008371
# objective function = 5.732753696025075
# optimal point is = 0.8388901296728204
# objective function = 5.703736649662481
# optimal point is = 0.822112327079364
# objective function = 5.675868678335847
# optimal point is = 0.8056700805377767
# objective function = 5.6491042786737475
# optimal point is = 0.7895566789270211
# objective function = 5.623399749238267
# optimal point is = 0.7737655453484806
# objective function = 5.598713119168432
# optimal point is = 0.758290234441511
# objective function = 5.575004079649362
# optimal point is = 0.7431244297526808
# objective function = 5.552233918095247
# optimal point is = 0.7282619411576272
# objective function = 5.530365454938675
# optimal point is = 0.7136967023344747
# objective function = 5.509362982923104
# optimal point is = 0.6994227682877852
# objective function = 5.4891922087993485
# optimal point is = 0.6854343129220295
# objective function = 5.469820197330895
# optimal point is = 0.6717256266635889
# objective function = 5.451215317516591
# optimal point is = 0.6582911141303172
# objective function = 5.433347190942934
# optimal point is = 0.6451252918477108
# objective function = 5.416186642181594
# optimal point is = 0.6322227860107567
# objective function = 5.399705651151203
# optimal point is = 0.6195783302905415
# objective function = 5.383877307365616
# optimal point is = 0.6071867636847307
# objective function = 5.368675765993937
# optimal point is = 0.5950430284110361
# objective function = 5.3540762056605775
# optimal point is = 0.5831421678428154
# objective function = 5.340054787916419
# optimal point is = 0.5714793244859591
# objective function = 5.326588618314928
# optimal point is = 0.5600497379962399
# objective function = 5.313655709029657
# optimal point is = 0.5488487432363152
# objective function = 5.301234942952083
# optimal point is = 0.5378717683715889
# objective function = 5.28930603921118
# optimal point is = 0.5271143330041571
# objective function = 5.2778495200584175
# optimal point is = 0.5165720463440739
# objective function = 5.266846679064104
# optimal point is = 0.5062406054171925
# objective function = 5.256279550573166
# optimal point is = 0.49611579330884864
# objective function = 5.246130880370468
# optimal point is = 0.48619347744267166
# objective function = 5.2363840975077975
# optimal point is = 0.4764696078938182
# objective function = 5.227023287246489
# optimal point is = 0.46694021573594185
# objective function = 5.218033165071528
# optimal point is = 0.457601411421223
# objective function = 5.209399051734695
# optimal point is = 0.44844938319279853
# objective function = 5.201106849286002
# optimal point is = 0.4394803955289426
# objective function = 5.1931430180542755
# optimal point is = 0.4306907876183637
# objective function = 5.185494554539327
# optimal point is = 0.42207697186599646
# objective function = 5.178148970179569
# optimal point is = 0.4136354324286765
# objective function = 5.171094270960459
# optimal point is = 0.40536272378010296
# objective function = 5.164318937830424
# optimal point is = 0.3972554693045009
# objective function = 5.15781190789234
# optimal point is = 0.3893103599184109
# objective function = 5.151562556339803
# optimal point is = 0.3815241527200427
# objective function = 5.145560679108747
# optimal point is = 0.37389366966564186
# objective function = 5.13979647621604
# optimal point is = 0.366415796272329
# objective function = 5.1342605357578845
# optimal point is = 0.3590874803468824
# objective function = 5.128943818541873
# optimal point is = 0.3519057307399448
# objective function = 5.123837643327614
# optimal point is = 0.3448676161251459
# objective function = 5.118933672651841
# optimal point is = 0.33797026380264295
# objective function = 5.114223899214828
# optimal point is = 0.3312108585265901
# objective function = 5.109700632805921
# optimal point is = 0.3245866413560583
# objective function = 5.105356487746806
# optimal point is = 0.3180949085289371
# objective function = 5.101184370832033
# optimal point is = 0.3117330103583584
# objective function = 5.097177469747084
# optimal point is = 0.3054983501511912
# objective function = 5.0933292419451
# optimal point is = 0.2993883831481674
# objective function = 5.089633403964074
# optimal point is = 0.2934006154852041
# objective function = 5.086083921167097
# optimal point is = 0.2875326031755
# objective function = 5.08267499788888
# optimal point is = 0.28178195111199
# objective function = 5.07940106797248
# optimal point is = 0.2761463120897502
# objective function = 5.07625678568077
# optimal point is = 0.2706233858479552
# objective function = 5.073237016967811
# optimal point is = 0.2652109181309961
# objective function = 5.070336831095886
# optimal point is = 0.2599066997683762
# objective function = 5.067551492584489
# optimal point is = 0.2547085657730087
# objective function = 5.064876453478143
# optimal point is = 0.24961439445754854
# objective function = 5.062307345920408
# optimal point is = 0.24462210656839758
# objective function = 5.05983997502196
# optimal point is = 0.23972966443702964
# objective function = 5.057470312011091
# optimal point is = 0.23493507114828904
# objective function = 5.055194487655451
# optimal point is = 0.23023636972532327
# objective function = 5.053008785944296
# optimal point is = 0.2256316423308168
# objective function = 5.050909638020902
# optimal point is = 0.22111900948420046
# objective function = 5.048893616355274
# optimal point is = 0.21669662929451644
# objective function = 5.046957429147605
# optimal point is = 0.21236269670862612
# objective function = 5.04509791495336
# optimal point is = 0.2081154427744536
# objective function = 5.043312037521207
# optimal point is = 0.20395313391896452
# objective function = 5.0415968808353675
# optimal point is = 0.19987407124058523
# objective function = 5.039949644354286
# optimal point is = 0.19587658981577352
# objective function = 5.038367638437856
# optimal point is = 0.19195905801945806
# objective function = 5.036848279955717
# optimal point is = 0.1881198768590689
# objective function = 5.035389088069471
# optimal point is = 0.1843574793218875
# objective function = 5.03398768018192
# optimal point is = 0.18067032973544975
# objective function = 5.032641768046716
# optimal point is = 0.17705692314074076
# objective function = 5.031349154032066
# optimal point is = 0.17351578467792594
# objective function = 5.030107727532396
# optimal point is = 0.17004546898436743
# objective function = 5.028915461522113
# optimal point is = 0.16664455960468008
# objective function = 5.0277704092458375
# optimal point is = 0.16331166841258649
# objective function = 5.026670701039703
# optimal point is = 0.16004543504433474
# objective function = 5.0256145412785305
# optimal point is = 0.15684452634344806
# objective function = 5.0246002054439005
# optimal point is = 0.1537076358165791
# objective function = 5.023626037308322
# optimal point is = 0.15063348310024752
# objective function = 5.0226904462309125
# optimal point is = 0.14762081343824257
# objective function = 5.021791904560168
# optimal point is = 0.1446683971694777
# objective function = 5.020928945139586
# optimal point is = 0.14177502922608817
# objective function = 5.020100158912058
# optimal point is = 0.13893952864156642
# objective function = 5.019304192619141
# optimal point is = 0.13616073806873508
# objective function = 5.018539746591423
# optimal point is = 0.13343752330736036
# objective function = 5.017805572626402
# optimal point is = 0.13076877284121316
# objective function = 5.017100471950397
# optimal point is = 0.12815339738438888
# objective function = 5.016423293261161
# optimal point is = 0.12559032943670112
# objective function = 5.015772930848019
# optimal point is = 0.1230785228479671
# objective function = 5.0151483227864375
# optimal point is = 0.12061695239100775
# objective function = 5.014548449204095
# optimal point is = 0.1182046133431876
# objective function = 5.013972330615612
# optimal point is = 0.11584052107632385
# objective function = 5.013419026323234
# optimal point is = 0.11352371065479737
# objective function = 5.012887632880834
# optimal point is = 0.11125323644170142
# objective function = 5.012377282618753
# optimal point is = 0.10902817171286738
# objective function = 5.01188714222705
# optimal point is = 0.10684760827861003
# objective function = 5.011416411394859
# optimal point is = 0.10471065611303783
# objective function = 5.010964321503623
# optimal point is = 0.10261644299077707
# objective function = 5.01053013437208
# optimal point is = 0.10056411413096153
# objective function = 5.010113141050945
# optimal point is = 0.09855283184834229
# objective function = 5.009712660665327
# optimal point is = 0.09658177521137545
# objective function = 5.00932803930298
# optimal point is = 0.09465013970714795
# objective function = 5.0089586489465825
# optimal point is = 0.09275713691300498
# objective function = 5.008603886448298
# optimal point is = 0.09090199417474489
# objective function = 5.008263172544946
# optimal point is = 0.08908395429124999
# objective function = 5.007935950912166
# optimal point is = 0.087302275205425
# objective function = 5.0076216872560435
# optimal point is = 0.08555622970131649
# objective function = 5.007319868440704
# optimal point is = 0.08384510510729015
# objective function = 5.0070300016504525
# optimal point is = 0.08216820300514435
# objective function = 5.006751613585094
# optimal point is = 0.08052483894504146
# objective function = 5.006484249687125
# optimal point is = 0.07891434216614063
# objective function = 5.006227473399515
# optimal point is = 0.07733605532281781
# objective function = 5.005980865452894
# optimal point is = 0.07578933421636146
# objective function = 5.005744023180959
# optimal point is = 0.07427354753203423
# objective function = 5.005516559862993
# optimal point is = 0.07278807658139355
# objective function = 5.005298104092419
# optimal point is = 0.07133231504976568
# objective function = 5.005088299170359
# optimal point is = 0.06990566874877037
# objective function = 5.004886802523213
# optimal point is = 0.06850755537379496
# objective function = 5.0046932851432935
# optimal point is = 0.06713740426631906
# objective function = 5.0045074310516195
# optimal point is = 0.06579465618099269
# objective function = 5.004328936781975
# optimal point is = 0.06447876305737284
# objective function = 5.004157510885409
# optimal point is = 0.06318918779622539
# objective function = 5.003992873454346
# optimal point is = 0.06192540404030088
# objective function = 5.0038347556655545
# optimal point is = 0.060686895959494856
# objective function = 5.003682899341198
# optimal point is = 0.05947315804030496
# objective function = 5.003537056527287
# optimal point is = 0.05828369487949886
# objective function = 5.003396989088807
# optimal point is = 0.05711802098190888
# objective function = 5.00326246832089
# optimal point is = 0.0559756605622707
# objective function = 5.003133274575383
# optimal point is = 0.054856147351025286
# objective function = 5.003009196902197
# optimal point is = 0.053759024404004783
# objective function = 5.002890032704871
# optimal point is = 0.05268384391592469
# objective function = 5.002775587409758
# optimal point is = 0.0516301670376062
# objective function = 5.002665674148331
# optimal point is = 0.05059756369685408
# objective function = 5.002560113452057
# optimal point is = 0.049585612422917
# objective function = 5.002458732959356
# optimal point is = 0.04859390017445866
# objective function = 5.002361367134165
# optimal point is = 0.04762202217096949
# objective function = 5.002267856995652
# optimal point is = 0.0466695817275501
# objective function = 5.002178049858625
# optimal point is = 0.0457361900929991
# objective function = 5.002091799084223
# optimal point is = 0.04482146629113912
# objective function = 5.002008963840487
# optimal point is = 0.043925036965316334
# objective function = 5.001929408872404
# optimal point is = 0.043046536226010006
# objective function = 5.001853004281057
# optimal point is = 0.04218560550148981
# objective function = 5.001779625311527
# optimal point is = 0.041341893391460015
# objective function = 5.001709152149191
# optimal point is = 0.040515055523630814
# objective function = 5.001641469724083
# optimal point is = 0.0397047544131582
# objective function = 5.001576467523009
# optimal point is = 0.038910659324895035
# objective function = 5.0015140394090984
# optimal point is = 0.038132446138397134
# objective function = 5.001454083448498
# optimal point is = 0.03736979721562919
# objective function = 5.001396501743938
# optimal point is = 0.03662240127131661
# objective function = 5.001341200274878
# optimal point is = 0.035889953245890276
# objective function = 5.001288088743992
# optimal point is = 0.03517215418097247
# objective function = 5.00123708042973
# optimal point is = 0.03446871109735302
# objective function = 5.001188092044713
# optimal point is = 0.03377933687540596
# objective function = 5.001141043599742
# optimal point is = 0.03310375013789785
# objective function = 5.001095858273192
# optimal point is = 0.03244167513513989
# objective function = 5.001052462285574
# optimal point is = 0.03179284163243709
# objective function = 5.001010784779065
# optimal point is = 0.03115698479978835
# objective function = 5.000970757701814
# optimal point is = 0.030533845103792583
# objective function = 5.000932315696822
# optimal point is = 0.02992316820171673
# objective function = 5.0008953959952285
# optimal point is = 0.029324704837682396
# objective function = 5.000859938313817
# optimal point is = 0.02873821074092875
# objective function = 5.00082588475659
# optimal point is = 0.028163446526110174
# objective function = 5.000793179720229
# optimal point is = 0.02760017759558797
# objective function = 5.000761769803308
# optimal point is = 0.027048174043676213
# objective function = 5.000731603719097
# optimal point is = 0.02650721056280269
# objective function = 5.000702632211821
# optimal point is = 0.025977066351546636
# objective function = 5.000674807976233
# optimal point is = 0.025457525024515704
# objective function = 5.000648085580374
# optimal point is = 0.024948374524025388
# objective function = 5.000622421391391
# optimal point is = 0.02444940703354488
# objective function = 5.000597773504292
# optimal point is = 0.023960418892873984
# objective function = 5.000574101673522
# optimal point is = 0.023481210515016504
# objective function = 5.00055136724725
# optimal point is = 0.023011586304716173
# objective function = 5.00052953310426
# optimal point is = 0.02255135457862185
# objective function = 5.000508563593331
# optimal point is = 0.022100327487049414
# objective function = 5.0004884244750345
# optimal point is = 0.021658320937308427
# objective function = 5.000469082865823
# optimal point is = 0.02122515451856226
# objective function = 5.000450507184337
# optimal point is = 0.020800651428191014
# objective function = 5.000432667099837
# optimal point is = 0.020384638399627193
# objective function = 5.000415533482683
# optimal point is = 0.01997694563163465
# objective function = 5.000399078356769
# optimal point is = 0.019577406719001957
# objective function = 5.000383274853841
# optimal point is = 0.019185858584621917
# objective function = 5.000368097169629
# optimal point is = 0.01880214141292948
# objective function = 5.000353520521712
# optimal point is = 0.01842609858467089
# objective function = 5.000339521109052
# optimal point is = 0.018057576612977473
# objective function = 5.000326076073134
# optimal point is = 0.017696425080717924
# objective function = 5.000313163460637
# optimal point is = 0.017342496579103566
# objective function = 5.000300762187596
# optimal point is = 0.016995646647521494
# objective function = 5.000288852004967
# optimal point is = 0.016655733714571064
# objective function = 5.000277413465571
# optimal point is = 0.016322619040279644
# objective function = 5.000266427892334
# optimal point is = 0.01599616665947405
# objective function = 5.000255877347798
# optimal point is = 0.015676243326284568
# objective function = 5.0002457446048245
# optimal point is = 0.015362718459758878
# objective function = 5.0002360131184735
# optimal point is = 0.0150554640905637
# objective function = 5.000226666998982
# optimal point is = 0.014754354808752425
# objective function = 5.0002176909858225
# optimal point is = 0.014459267712577377
# objective function = 5.000209070422784
# optimal point is = 0.01417008235832583
# objective function = 5.000200791234041
# optimal point is = 0.013886680711159312
# objective function = 5.000192839901174
# optimal point is = 0.013608947096936126
# objective function = 5.000185203441087
# optimal point is = 0.013336768154997403
# objective function = 5.00017786938482
# optimal point is = 0.013070032791897454
# objective function = 5.0001708257571815
# optimal point is = 0.012808632136059506
# objective function = 5.0001640610571965
# optimal point is = 0.012552459493338317
# objective function = 5.000157564239332
# optimal point is = 0.01230141030347155
# objective function = 5.000151324695454
# optimal point is = 0.01205538209740212
# objective function = 5.000145332237515
# optimal point is = 0.011814274455454077
# objective function = 5.000139577080909
# optimal point is = 0.011577988966344994
# objective function = 5.000134049828505
# optimal point is = 0.011346429187018095
# objective function = 5.000128741455296
# optimal point is = 0.011119500603277734
# objective function = 5.000123643293667
# optimal point is = 0.01089711059121218
# objective function = 5.000118747019237
# optimal point is = 0.010679168379387935
# objective function = 5.000114044637275
# optimal point is = 0.010465585011800177
# objective function = 5.000109528469639
# optimal point is = 0.010256273311564174
# objective function = 5.000105191142241
# optimal point is = 0.01005114784533289
# objective function = 5.0001010255730085
# optimal point is = 0.009850124888426232
# objective function = 5.000097024960318
# optimal point is = 0.009653122390657708
# objective function = 5.000093182771889
# optimal point is = 0.009460059942844554
# objective function = 5.000089492734122
# optimal point is = 0.009270858743987663
# objective function = 5.000085948821851
# optimal point is = 0.00908544156910791
# objective function = 5.000082545248506
# optimal point is = 0.008903732737725751
# objective function = 5.000079276456665
# optimal point is = 0.008725658082971237
# objective function = 5.000076137108981
# optimal point is = 0.008551144921311812
# objective function = 5.000073122079465
# optimal point is = 0.008380122022885576
# objective function = 5.000070226445119
# optimal point is = 0.008212519582427864
# objective function = 5.0000674454778915
# optimal point is = 0.008048269190779308
# objective function = 5.000064774636967
# optimal point is = 0.007887303806963722
# objective function = 5.000062209561343
# optimal point is = 0.007729557730824447
# objective function = 5.000059746062714
# optimal point is = 0.007574966576207958
# objective function = 5.000057380118631
# optimal point is = 0.007423467244683799
# objective function = 5.000055107865933
# optimal point is = 0.007274997899790123
# objective function = 5.000052925594442
# optimal point is = 0.00712949794179432
# objective function = 5.000050829740902
# optimal point is = 0.006986907982958433
# objective function = 5.0000488168831625
# optimal point is = 0.006847169823299264
# objective function = 5.000046883734589
# optimal point is = 0.0067102264268332785
# objective function = 5.000045027138699
# optimal point is = 0.006576021898296613
# objective function = 5.000043244064007
# optimal point is = 0.006444501460330681
# objective function = 5.000041531599072
# optimal point is = 0.0063156114311240675
# objective function = 5.000039886947749
# optimal point is = 0.006189299202501586
# objective function = 5.000038307424618
# optimal point is = 0.006065513218451554
# objective function = 5.000036790450603
# optimal point is = 0.005944202954082523
# objective function = 5.00003533354876
# optimal point is = 0.005825318895000872
# objective function = 5.0000339343402285
# optimal point is = 0.005708812517100855
# objective function = 5.000032590540355
# optimal point is = 0.005594636266758838
# objective function = 5.000031299954958
# optimal point is = 0.005482743541423661
# objective function = 5.000030060476741
# optimal point is = 0.005373088670595188
# objective function = 5.000028870081862
# optimal point is = 0.005265626897183284
# objective function = 5.0000277268266204
# optimal point is = 0.005160314359239618
# objective function = 5.000026628844286
# optimal point is = 0.005057108072054826
# objective function = 5.000025574342052
# optimal point is = 0.004955965910613729
# objective function = 5.000024561598107
# optimal point is = 0.004856846592401455
# objective function = 5.000023588958822
# optimal point is = 0.004759709660553426
# objective function = 5.0000226548360525
# optimal point is = 0.004664515467342358
# objective function = 5.000021757704545
# optimal point is = 0.004571225157995511
# objective function = 5.0000208960994454
# optimal point is = 0.004479800654835601
# objective function = 5.000020068613907
# optimal point is = 0.004390204641738889
# objective function = 5.000019273896796
# optimal point is = 0.004302400548904111
# objective function = 5.0000185106504835
# optimal point is = 0.004216352537926029
# objective function = 5.000017777628724
# optimal point is = 0.004132025487167509
# objective function = 5.000017073634627
# optimal point is = 0.004049384977424159
# objective function = 5.000016397518696
# optimal point is = 0.003968397277875676
# objective function = 5.000015748176955
# optimal point is = 0.003889029332318162
# objective function = 5.000015124549147
# optimal point is = 0.0038112487456717988
# objective function = 5.000014525617002
# optimal point is = 0.0037350237707583626
# objective function = 5.000013950402568
# optimal point is = 0.0036603232953431953
# objective function = 5.000013397966627
# optimal point is = 0.0035871168294363313
# objective function = 5.000012867407148
# optimal point is = 0.0035153744928476047
# objective function = 5.000012357857825
# optimal point is = 0.0034450670029906524
# objective function = 5.000011868486655
# optimal point is = 0.0033761656629308395
# objective function = 5.000011398494584
# optimal point is = 0.0033086423496722227
# objective function = 5.000010947114198
# optimal point is = 0.0032424695026787784
# objective function = 5.000010513608475
# optimal point is = 0.003177620112625203
# objective function = 5.0000100972695805
# optimal point is = 0.003114067710372699
# objective function = 5.000009697417704
# optimal point is = 0.0030517863561652448
# objective function = 5.000009313399963
# optimal point is = 0.00299075062904194
# objective function = 5.000008944589325
# optimal point is = 0.0029309356164611013
# objective function = 5.000008590383588
# optimal point is = 0.0028723169041318794
# objective function = 5.000008250204398
# optimal point is = 0.002814870566049242
# objective function = 5.0000079234963035
# optimal point is = 0.002758573154728257
# objective function = 5.00000760972585
# optimal point is = 0.002703401691633692
# objective function = 5.000007308380706
# optimal point is = 0.0026493336578010183
# objective function = 5.00000701896883
# optimal point is = 0.002596346984644998
# objective function = 5.000006741017665
# optimal point is = 0.0025444200449520984
# objective function = 5.000006474073365
# optimal point is = 0.0024935316440530563
# objective function = 5.00000621770006
# optimal point is = 0.0024436610111719954
# objective function = 5.000005971479138
# optimal point is = 0.0023947877909485556
# objective function = 5.000005735008564
# optimal point is = 0.0023468920351295843
# objective function = 5.000005507902225
# optimal point is = 0.0022999541944269926
# objective function = 5.000005289789296
# optimal point is = 0.0022539551105384527
# objective function = 5.00000508031364
# optimal point is = 0.002208876008327684
# objective function = 5.00000487913322
# optimal point is = 0.00216469848816113
# objective function = 5.000004685919545
# optimal point is = 0.0021214045183979074
# objective function = 5.0000045003571305
# optimal point is = 0.0020789764280299493
# objective function = 5.000004322142988
# optimal point is = 0.0020373968994693505
# objective function = 5.000004150986126
# optimal point is = 0.0019966489614799635
# objective function = 5.000003986607076
# optimal point is = 0.0019567159822503643
# objective function = 5.0000038287374355
# optimal point is = 0.001917581662605357
# objective function = 5.000003677119433
# optimal point is = 0.00187923002935325
# objective function = 5.000003531505503
# optimal point is = 0.0018416454287661851
# objective function = 5.000003391657885
# optimal point is = 0.0018048125201908613
# objective function = 5.000003257348233
# optimal point is = 0.001768716269787044
# objective function = 5.000003128357243
# optimal point is = 0.0017333419443913032
# objective function = 5.000003004474296
# optimal point is = 0.0016986751055034772
# objective function = 5.000002885497114
# optimal point is = 0.0016647016033934077
# objective function = 5.000002771231428
# optimal point is = 0.0016314075713255395
# objective function = 5.000002661490663
# optimal point is = 0.0015987794198990288
# objective function = 5.000002556095634
# optimal point is = 0.0015668038315010482
# objective function = 5.000002454874246
# optimal point is = 0.0015354677548710272
# objective function = 5.000002357661226
# optimal point is = 0.0015047583997736067
# objective function = 5.000002264297842
# optimal point is = 0.0014746632317781346
# objective function = 5.000002174631647
# optimal point is = 0.001445169967142572
# objective function = 5.000002088516234
# optimal point is = 0.0014162665677997207
# objective function = 5.000002005810991
# optimal point is = 0.0013879412364437263
# objective function = 5.000001926380876
# optimal point is = 0.0013601824117148518
# objective function = 5.000001850096194
# optimal point is = 0.0013329787634805547
# objective function = 5.0000017768323834
# optimal point is = 0.0013063191882109436
# objective function = 5.0000017064698214
# optimal point is = 0.0012801928044467248
# objective function = 5.000001638893616
# optimal point is = 0.0012545889483577904
# objective function = 5.000001573993429
# optimal point is = 0.0012294971693906345
# objective function = 5.00000151166329
# optimal point is = 0.0012049072260028218
# objective function = 5.000001451801423
# optimal point is = 0.0011808090814827653
# objective function = 5.000001394310087
# optimal point is = 0.00115719289985311
# objective function = 5.000001339095408
# optimal point is = 0.0011340490418560477
# objective function = 5.00000128606723
# optimal point is = 0.0011113680610189268
# objective function = 5.000001235138967
# optimal point is = 0.0010891406997985483
# objective function = 5.000001186227464
# optimal point is = 0.0010673578858025772
# objective function = 5.0000011392528565
# optimal point is = 0.0010460107280865257
# objective function = 5.000001094138443
# optimal point is = 0.0010250905135247952
# objective function = 5.000001050810561
# optimal point is = 0.0010045887032542992
# objective function = 5.000001009198463
# optimal point is = 0.0009844969291892133
# objective function = 5.000000969234204
# optimal point is = 0.000964806990605429
# objective function = 5.000000930852529
# optimal point is = 0.0009455108507933204
# objective function = 5.0000008939907685
# optimal point is = 0.000926600633777454
# objective function = 5.000000858588734
# optimal point is = 0.0009080686211019049
# objective function = 5.0000008245886205
# optimal point is = 0.0008899072486798667
# objective function = 5.000000791934911
# optimal point is = 0.0008721091037062694
# objective function = 5.000000760574289
# optimal point is = 0.000854666921632144
# objective function = 5.000000730455547
# optimal point is = 0.0008375735831995012
# objective function = 5.000000701529507
# optimal point is = 0.0008208221115355111
# objective function = 5.000000673748938
# optimal point is = 0.0008044056693048008
# objective function = 5.000000647068481
# optimal point is = 0.0007883175559187048
# objective function = 5.000000621444569
# optimal point is = 0.0007725512048003307
# objective function = 5.000000596835364
# optimal point is = 0.000757100180704324
# objective function = 5.000000573200683
# optimal point is = 0.0007419581770902376
# objective function = 5.0000005505019365
# optimal point is = 0.0007271190135484328
# objective function = 5.00000052870206
# optimal point is = 0.0007125766332774641
# objective function = 5.000000507765458
# optimal point is = 0.0006983251006119148
# objective function = 5.000000487657946
# optimal point is = 0.0006843585985996765
# objective function = 5.000000468346691
# optimal point is = 0.0006706714266276829
# objective function = 5.0000004498001624
# optimal point is = 0.0006572579980951293
# objective function = 5.000000431988076
# optimal point is = 0.0006441128381332267
# objective function = 5.000000414881348
# optimal point is = 0.0006312305813705622
# objective function = 5.0000003984520465
# optimal point is = 0.000618605969743151
# objective function = 5.0000003826733455
# optimal point is = 0.000606233850348288
# objective function = 5.0000003675194815
# optimal point is = 0.0005941091733413222
# objective function = 5.00000035296571
# optimal point is = 0.0005822269898744958
# objective function = 5.000000338988268
# optimal point is = 0.0005705824500770059
# objective function = 5.000000325564332
# optimal point is = 0.0005591708010754657
# objective function = 5.000000312671985
# optimal point is = 0.0005479873850539564
# objective function = 5.000000300290174
# optimal point is = 0.0005370276373528772
# objective function = 5.000000288398684
# optimal point is = 0.0005262870846058197
# objective function = 5.000000276978096
# optimal point is = 0.0005157613429137033
# objective function = 5.000000266009763
# optimal point is = 0.0005054461160554293
# objective function = 5.0000002554757765
# optimal point is = 0.0004953371937343207
# objective function = 5.000000245358936
# optimal point is = 0.00048543044985963426
# objective function = 5.000000235642721
# optimal point is = 0.0004757218408624416
# objective function = 5.00000022631127
# optimal point is = 0.00046620740404519276
# objective function = 5.000000217349344
# optimal point is = 0.00045688325596428893
# objective function = 5.00000020874231
# optimal point is = 0.0004477455908450032
# objective function = 5.000000200476114
# optimal point is = 0.0004387906790281031
# objective function = 5.00000019253726
# optimal point is = 0.00043001486544754104
# objective function = 5.000000184912785
# optimal point is = 0.0004214145681385902
# objective function = 5.0000001775902385
# optimal point is = 0.0004129862767758184
# objective function = 5.000000170557665
# optimal point is = 0.00040472655124030205
# objective function = 5.000000163803581
# optimal point is = 0.000396632020215496
# objective function = 5.0000001573169595
# optimal point is = 0.0003886993798111861
# objective function = 5.000000151087208
# optimal point is = 0.0003809253922149624
# objective function = 5.0000001451041545
# optimal point is = 0.00037330688437066313
# objective function = 5.00000013935803
# optimal point is = 0.0003658407466832499
# objective function = 5.0000001338394515
# optimal point is = 0.0003585239317495849
# objective function = 5.000000128539409
# optimal point is = 0.0003513534531145932
# objective function = 5.000000123449249
# optimal point is = 0.00034432638405230135
# objective function = 5.000000118560659
# optimal point is = 0.0003374398563712553
# objective function = 5.0000001138656565
# optimal point is = 0.0003306910592438302
# objective function = 5.000000109356576
# optimal point is = 0.0003240772380589536
# objective function = 5.000000105026056
# optimal point is = 0.00031759569329777455
# objective function = 5.000000100867024
# optimal point is = 0.00031124377943181906
# objective function = 5.00000009687269
# optimal point is = 0.0003050189038431827
# objective function = 5.000000093036531
# optimal point is = 0.00029891852576631906
# objective function = 5.000000089352285
# optimal point is = 0.00029294015525099267
# objective function = 5.000000085813935
# optimal point is = 0.0002870813521459728
# objective function = 5.000000082415703
# optimal point is = 0.00028133972510305336
# objective function = 5.0000000791520405
# optimal point is = 0.0002757129306009923
# objective function = 5.00000007601762
# optimal point is = 0.0002701986719889725
# objective function = 5.000000073007322
# optimal point is = 0.00026479469854919304
# objective function = 5.000000070116233
# optimal point is = 0.00025949880457820917
# objective function = 5.00000006733963
# optimal point is = 0.000254308828486645
# objective function = 5.00000006467298
# optimal point is = 0.00024922265191691206
# objective function = 5.00000006211193
# optimal point is = 0.0002442381988785738
# objective function = 5.000000059652298
# optimal point is = 0.00023935343490100232
# objective function = 5.000000057290067
# optimal point is = 0.00023456636620298226
# objective function = 5.00000005502138
# optimal point is = 0.00022987503887892261
# objective function = 5.000000052842534
# optimal point is = 0.00022527753810134415
# objective function = 5.00000005074997
# optimal point is = 0.00022077198733931727
# objective function = 5.0000000487402705
# optimal point is = 0.00021635654759253093
# objective function = 5.000000046810156
# optimal point is = 0.00021202941664068032
# objective function = 5.000000044956473
# optimal point is = 0.0002077888283078667
# objective function = 5.000000043176197
# optimal point is = 0.00020363305174170935
# objective function = 5.00000004146642
# optimal point is = 0.00019956039070687516
# objective function = 5.000000039824349
# optimal point is = 0.00019556918289273767
# objective function = 5.000000038247305
# optimal point is = 0.00019165779923488292
# objective function = 5.000000036732712
# optimal point is = 0.00018782464325018525
# objective function = 5.000000035278097
# optimal point is = 0.00018406815038518153
# objective function = 5.000000033881084
# optimal point is = 0.0001803867873774779
# objective function = 5.000000032539393
# optimal point is = 0.00017677905162992834
# objective function = 5.000000031250833
# optimal point is = 0.00017324347059732978
# objective function = 5.0000000300133
# optimal point is = 0.00016977860118538317
# objective function = 5.000000028824774
# optimal point is = 0.0001663830291616755
# objective function = 5.0000000276833125
# optimal point is = 0.000163055368578442
# objective function = 5.0000000265870534
# optimal point is = 0.00015979426120687316
# objective function = 5.000000025534206
# optimal point is = 0.0001565983759827357
# objective function = 5.000000024523051
# optimal point is = 0.00015346640846308098
# objective function = 5.000000023551938
# optimal point is = 0.00015039708029381937
# objective function = 5.000000022619282
# optimal point is = 0.000147389138687943
# objective function = 5.000000021723558
# optimal point is = 0.00014444135591418412
# objective function = 5.000000020863305
# optimal point is = 0.00014155252879590043
# objective function = 5.000000020037119
# optimal point is = 0.00013872147821998243
# objective function = 5.0000000192436485
# optimal point is = 0.00013594704865558277
# objective function = 5.0000000184816
# optimal point is = 0.00013322810768247111
# objective function = 5.000000017749729
# optimal point is = 0.0001305635455288217
# objective function = 5.0000000170468395
# optimal point is = 0.00012795227461824527
# objective function = 5.000000016371785
# optimal point is = 0.00012539322912588036
# objective function = 5.000000015723462
# optimal point is = 0.00012288536454336277
# objective function = 5.000000015100813
# optimal point is = 0.00012042765725249552
# objective function = 5.00000001450282
# optimal point is = 0.0001180191041074456
# objective function = 5.000000013928509
# optimal point is = 0.00011565872202529668
# objective function = 5.00000001337694
# optimal point is = 0.00011334554758479075
# objective function = 5.000000012847213
# optimal point is = 0.00011107863663309494
# objective function = 5.000000012338464
# optimal point is = 0.00010885706390043305
# objective function = 5.000000011849861
# optimal point is = 0.00010667992262242438
# objective function = 5.000000011380606
# optimal point is = 0.0001045463241699759
# objective function = 5.000000010929934
# optimal point is = 0.00010245539768657637
# objective function = 5.000000010497108
# optimal point is = 0.00010040628973284484
# objective function = 5.000000010081423
# optimal point is = 9.839816393818794e-05
# objective function = 5.000000009682199
# optimal point is = 9.643020065942417e-05
# objective function = 5.000000009298784
# optimal point is = 9.45015966462357e-05
# objective function = 5.000000008930551
# optimal point is = 9.261156471331098e-05
# objective function = 5.000000008576902
# optimal point is = 9.075933341904476e-05
# objective function = 5.000000008237256
# optimal point is = 8.894414675066387e-05
# objective function = 5.000000007911061
# optimal point is = 8.71652638156506e-05
# objective function = 5.000000007597783
# optimal point is = 8.542195853933758e-05
# objective function = 5.000000007296911
# optimal point is = 8.371351936855083e-05
# objective function = 5.000000007007953
# optimal point is = 8.203924898117981e-05
# objective function = 5.000000006730438
# optimal point is = 8.039846400155621e-05
# objective function = 5.000000006463913
# optimal point is = 7.879049472152508e-05
# objective function = 5.000000006207942
# optimal point is = 7.721468482709458e-05
# objective function = 5.000000005962107
# optimal point is = 7.567039113055268e-05
# objective function = 5.000000005726008
# optimal point is = 7.415698330794162e-05
# objective function = 5.000000005499258
# optimal point is = 7.267384364178279e-05
# objective function = 5.000000005281487
# optimal point is = 7.122036676894714e-05
# objective function = 5.000000005072341
# optimal point is = 6.979595943356819e-05
# objective function = 5.000000004871476
# optimal point is = 6.840004024489682e-05
# objective function = 5.000000004678565
# optimal point is = 6.703203943999888e-05
# objective function = 5.000000004493295
# optimal point is = 6.56913986511989e-05
# objective function = 5.00000000431536
# optimal point is = 6.437757067817492e-05
# objective function = 5.000000004144471
# optimal point is = 6.309001926461143e-05
# objective function = 5.00000000398035
# optimal point is = 6.18282188793192e-05
# objective function = 5.000000003822729
# optimal point is = 6.0591654501732816e-05
# objective function = 5.000000003671349
# optimal point is = 5.937982141169816e-05
# objective function = 5.0000000035259635
# optimal point is = 5.81922249834642e-05
# objective function = 5.000000003386335
# optimal point is = 5.702838048379491e-05
# objective function = 5.000000003252236
# optimal point is = 5.588781287411901e-05
# objective function = 5.000000003123447
# optimal point is = 5.477005661663663e-05
# objective function = 5.000000002999759
# optimal point is = 5.3674655484303895e-05
# objective function = 5.000000002880968
# optimal point is = 5.2601162374617814e-05
# objective function = 5.000000002766883
# optimal point is = 5.154913912712546e-05
# objective function = 5.0000000026573135
# optimal point is = 5.051815634458295e-05
# objective function = 5.000000002552084
# optimal point is = 4.950779321769129e-05
# objective function = 5.000000002451022
# optimal point is = 4.851763735333746e-05
# objective function = 5.0000000023539615
# optimal point is = 4.754728460627071e-05
# objective function = 5.0000000022607445
# optimal point is = 4.6596338914145296e-05
# objective function = 5.000000002171219
# optimal point is = 4.566441213586239e-05
# objective function = 5.000000002085239
# optimal point is = 4.4751123893145145e-05
# objective function = 5.000000002002663
# optimal point is = 4.385610141528224e-05
# objective function = 5.0000000019233575
# optimal point is = 4.2978979386976596e-05
# objective function = 5.000000001847193
# optimal point is = 4.2119399799237066e-05
# objective function = 5.000000001774044
# optimal point is = 4.127701180325232e-05
# objective function = 5.000000001703792
# ...
# objective function = 5.0
# optimal point is = 2.1592395970056273e-85
# objective function = 5.0
# optimal point is = 2.1160548050655146e-85
# objective function = 5.0
# optimal point is = 2.0737337089642043e-85
# objective function = 5.0
# optimal point is = 2.0322590347849203e-85
# objective function = 5.0
# optimal point is = 1.9916138540892218e-85
# objective function = 5.0
# optimal point is = 1.9517815770074374e-85
# objective function = 5.0
# optimal point is = 1.9127459454672886e-85
# objective function = 5.0
# optimal point is = 1.8744910265579428e-85
# objective function = 5.0
# optimal point is = 1.8370012060267839e-85
# objective function = 5.0
# optimal point is = 1.8002611819062482e-85
# objective function = 5.0
# optimal point is = 1.7642559582681233e-85
# objective function = 5.0
# optimal point is = 1.728970839102761e-85
# objective function = 5.0
# optimal point is = 1.6943914223207056e-85
# objective function = 5.0
# optimal point is = 1.6605035938742914e-85
# objective function = 5.0
# optimal point is = 1.6272935219968056e-85
# objective function = 5.0
# optimal point is = 1.5947476515568694e-85
# objective function = 5.0
# optimal point is = 1.562852698525732e-85
# objective function = 5.0
# optimal point is = 1.5315956445552172e-85
# objective function = 5.0
# optimal point is = 1.5009637316641128e-85
# objective function = 5.0
# optimal point is = 1.4709444570308306e-85
# objective function = 5.0
# optimal point is = 1.441525567890214e-85
# objective function = 5.0
# optimal point is = 1.4126950565324095e-85
# objective function = 5.0
# optimal point is = 1.384441155401761e-85
# objective function = 5.0
# optimal point is = 1.356752332293726e-85
# objective function = 5.0
# optimal point is = 1.3296172856478513e-85
# objective function = 5.0
# optimal point is = 1.3030249399348943e-85
# objective function = 5.0
# optimal point is = 1.2769644411361964e-85
# objective function = 5.0
# optimal point is = 1.2514251523134725e-85
# objective function = 5.0
# optimal point is = 1.226396649267203e-85
# objective function = 5.0
# optimal point is = 1.201868716281859e-85
# objective function = 5.0
# optimal point is = 1.1778313419562218e-85
# objective function = 5.0
# optimal point is = 1.1542747151170974e-85
# objective function = 5.0
# optimal point is = 1.1311892208147554e-85
# objective function = 5.0
# optimal point is = 1.1085654363984604e-85
# objective function = 5.0
# optimal point is = 1.0863941276704913e-85
# objective function = 5.0
# optimal point is = 1.0646662451170814e-85
# objective function = 5.0
# optimal point is = 1.0433729202147397e-85
# objective function = 5.0
# optimal point is = 1.022505461810445e-85
# objective function = 5.0
# optimal point is = 1.002055352574236e-85
# objective function = 5.0
# optimal point is = 9.820142455227514e-86
# objective function = 5.0
# optimal point is = 9.623739606122964e-86
# objective function = 5.0
# optimal point is = 9.431264814000505e-86
# objective function = 5.0
# optimal point is = 9.242639517720494e-86
# objective function = 5.0
# optimal point is = 9.057786727366085e-86
# objective function = 5.0
# optimal point is = 8.876630992818764e-86
# objective function = 5.0
# optimal point is = 8.699098372962388e-86
# objective function = 5.0
# optimal point is = 8.52511640550314e-86
# objective function = 5.0
# optimal point is = 8.354614077393077e-86
# objective function = 5.0
# optimal point is = 8.187521795845216e-86
# objective function = 5.0
# optimal point is = 8.023771359928311e-86
# objective function = 5.0
# optimal point is = 7.863295932729745e-86
# objective function = 5.0
# optimal point is = 7.70603001407515e-86
# objective function = 5.0
# optimal point is = 7.551909413793648e-86
# objective function = 5.0
# optimal point is = 7.400871225517775e-86
# objective function = 5.0
# optimal point is = 7.252853801007419e-86
# objective function = 5.0
# optimal point is = 7.10779672498727e-86
# objective function = 5.0
# optimal point is = 6.965640790487524e-86
# objective function = 5.0
# optimal point is = 6.826327974677775e-86
# objective function = 5.0
# optimal point is = 6.68980141518422e-86
# objective function = 5.0
# optimal point is = 6.556005386880535e-86
# objective function = 5.0
# optimal point is = 6.4248852791429246e-86
# objective function = 5.0
# optimal point is = 6.296387573560066e-86
# objective function = 5.0
# optimal point is = 6.170459822088865e-86
# objective function = 5.0
# optimal point is = 6.0470506256470875e-86
# objective function = 5.0
# optimal point is = 5.9261096131341456e-86
# objective function = 5.0
# optimal point is = 5.8075874208714625e-86
# objective function = 5.0
# optimal point is = 5.6914356724540334e-86
# objective function = 5.0
# optimal point is = 5.577606959004953e-86
# objective function = 5.0
# optimal point is = 5.466054819824854e-86
# objective function = 5.0
# optimal point is = 5.3567337234283565e-86
# objective function = 5.0
# optimal point is = 5.2495990489597894e-86
# objective function = 5.0
# optimal point is = 5.144607067980594e-86
# objective function = 5.0
# optimal point is = 5.0417149266209816e-86
# objective function = 5.0
# optimal point is = 4.940880628088562e-86
# objective function = 5.0
# optimal point is = 4.8420630155267906e-86
# objective function = 5.0
# optimal point is = 4.7452217552162545e-86
# objective function = 5.0
# optimal point is = 4.650317320111929e-86
# objective function = 5.0
# optimal point is = 4.557310973709691e-86
# objective function = 5.0
# optimal point is = 4.466164754235497e-86
# objective function = 5.0
# optimal point is = 4.376841459150787e-86
# objective function = 5.0
# optimal point is = 4.289304629967771e-86
# objective function = 5.0
# optimal point is = 4.203518537368416e-86
# objective function = 5.0
# optimal point is = 4.1194481666210476e-86
# objective function = 5.0
# optimal point is = 4.037059203288626e-86
# objective function = 5.0
# optimal point is = 3.9563180192228536e-86
# objective function = 5.0
# optimal point is = 3.8771916588383966e-86
# objective function = 5.0
# optimal point is = 3.7996478256616285e-86
# objective function = 5.0
# optimal point is = 3.723654869148396e-86
# objective function = 5.0
# optimal point is = 3.649181771765428e-86
# objective function = 5.0
# optimal point is = 3.576198136330119e-86
# objective function = 5.0
# optimal point is = 3.504674173603517e-86
# objective function = 5.0
# optimal point is = 3.4345806901314465e-86
# objective function = 5.0
# optimal point is = 3.365889076328817e-86
# objective function = 5.0
# optimal point is = 3.298571294802241e-86
# objective function = 5.0
# optimal point is = 3.232599868906196e-86
# objective function = 5.0
# optimal point is = 3.167947871528072e-86
# objective function = 5.0
# optimal point is = 3.1045889140975108e-86
# objective function = 5.0
# optimal point is = 3.0424971358155605e-86
# objective function = 5.0
# optimal point is = 2.9816471930992494e-86
# objective function = 5.0
# optimal point is = 2.9220142492372645e-86
# objective function = 5.0
# optimal point is = 2.863573964252519e-86
# objective function = 5.0
# optimal point is = 2.8063024849674687e-86
# objective function = 5.0
# optimal point is = 2.7501764352681192e-86
# objective function = 5.0
# optimal point is = 2.6951729065627567e-86
# objective function = 5.0
# optimal point is = 2.6412694484315017e-86
# objective function = 5.0
# optimal point is = 2.5884440594628717e-86
# objective function = 5.0
# optimal point is = 2.5366751782736144e-86
# objective function = 5.0
# optimal point is = 2.485941674708142e-86
# objective function = 5.0
# optimal point is = 2.4362228412139792e-86
# objective function = 5.0
# optimal point is = 2.3874983843896997e-86
# objective function = 5.0
# optimal point is = 2.3397484167019056e-86
# objective function = 5.0
# optimal point is = 2.2929534483678676e-86
# objective function = 5.0
# optimal point is = 2.2470943794005103e-86
# objective function = 5.0
# optimal point is = 2.2021524918125e-86
# objective function = 5.0
# optimal point is = 2.15810944197625e-86
# objective function = 5.0
# optimal point is = 2.1149472531367248e-86
# objective function = 5.0
# optimal point is = 2.0726483080739903e-86
# objective function = 5.0
# optimal point is = 2.0311953419125105e-86
# objective function = 5.0
# optimal point is = 1.9905714350742603e-86
# objective function = 5.0
# optimal point is = 1.950760006372775e-86
# objective function = 5.0
# optimal point is = 1.9117448062453194e-86
# objective function = 5.0
# optimal point is = 1.873509910120413e-86
# objective function = 5.0
# optimal point is = 1.8360397119180048e-86
# objective function = 5.0
# optimal point is = 1.7993189176796447e-86
# objective function = 5.0
# optimal point is = 1.763332539326052e-86
# objective function = 5.0
# optimal point is = 1.7280658885395308e-86
# objective function = 5.0
# optimal point is = 1.69350457076874e-86
# objective function = 5.0
# optimal point is = 1.6596344793533653e-86
# objective function = 5.0
# optimal point is = 1.6264417897662982e-86
# objective function = 5.0
# optimal point is = 1.5939129539709723e-86
# objective function = 5.0
# optimal point is = 1.5620346948915528e-86
# objective function = 5.0
# optimal point is = 1.5307940009937218e-86
# objective function = 5.0
# optimal point is = 1.5001781209738473e-86
# objective function = 5.0
# optimal point is = 1.4701745585543703e-86
# objective function = 5.0
# optimal point is = 1.440771067383283e-86
# objective function = 5.0
# optimal point is = 1.4119556460356172e-86
# objective function = 5.0
# optimal point is = 1.3837165331149048e-86
# objective function = 5.0
# optimal point is = 1.3560422024526068e-86
# objective function = 5.0
# optimal point is = 1.3289213584035546e-86
# objective function = 5.0
# optimal point is = 1.3023429312354836e-86
# objective function = 5.0
# optimal point is = 1.276296072610774e-86
# objective function = 5.0
# optimal point is = 1.2507701511585585e-86
# objective function = 5.0
# optimal point is = 1.2257547481353873e-86
# objective function = 5.0
# optimal point is = 1.2012396531726795e-86
# objective function = 5.0
# optimal point is = 1.1772148601092259e-86
# objective function = 5.0
# optimal point is = 1.1536705629070414e-86
# objective function = 5.0
# optimal point is = 1.1305971516489005e-86
# objective function = 5.0
# optimal point is = 1.1079852086159225e-86
# objective function = 5.0
# optimal point is = 1.085825504443604e-86
# objective function = 5.0
# optimal point is = 1.064108994354732e-86
# objective function = 5.0
# optimal point is = 1.0428268144676373e-86
# objective function = 5.0
# optimal point is = 1.0219702781782846e-86
# objective function = 5.0
# optimal point is = 1.0015308726147189e-86
# objective function = 5.0
# optimal point is = 9.815002551624245e-87
# objective function = 5.0
# optimal point is = 9.61870250059176e-87
# objective function = 5.0
# optimal point is = 9.426328450579926e-87
# objective function = 5.0
# optimal point is = 9.237801881568327e-87
# objective function = 5.0
# optimal point is = 9.053045843936962e-87
# objective function = 5.0
# optimal point is = 8.871984927058223e-87
# objective function = 5.0
# optimal point is = 8.694545228517058e-87
# objective function = 5.0
# optimal point is = 8.520654323946717e-87
# objective function = 5.0
# optimal point is = 8.350241237467783e-87
# objective function = 5.0
# optimal point is = 8.183236412718427e-87
# objective function = 5.0
# optimal point is = 8.019571684464058e-87
# objective function = 5.0
# optimal point is = 7.859180250774776e-87
# objective function = 5.0
# optimal point is = 7.701996645759281e-87
# objective function = 5.0
# optimal point is = 7.547956712844096e-87
# objective function = 5.0
# optimal point is = 7.396997578587214e-87
# objective function = 5.0
# optimal point is = 7.2490576270154695e-87
# objective function = 5.0
# optimal point is = 7.10407647447516e-87
# objective function = 5.0
# optimal point is = 6.961994944985657e-87
# objective function = 5.0
# optimal point is = 6.822755046085943e-87
# objective function = 5.0
# optimal point is = 6.686299945164224e-87
# objective function = 5.0
# optimal point is = 6.55257394626094e-87
# objective function = 5.0
# optimal point is = 6.421522467335721e-87
# objective function = 5.0
# optimal point is = 6.293092017989007e-87
# objective function = 5.0
# optimal point is = 6.167230177629227e-87
# objective function = 5.0
# optimal point is = 6.043885574076643e-87
# objective function = 5.0
# optimal point is = 5.92300786259511e-87
# objective function = 5.0
# optimal point is = 5.804547705343208e-87
# objective function = 5.0
# optimal point is = 5.6884567512363435e-87
# objective function = 5.0
# optimal point is = 5.574687616211617e-87
# objective function = 5.0
# optimal point is = 5.4631938638873845e-87
# objective function = 5.0
# optimal point is = 5.353929986609637e-87
# objective function = 5.0
# optimal point is = 5.246851386877444e-87
# objective function = 5.0
# optimal point is = 5.141914359139895e-87
# objective function = 5.0
# optimal point is = 5.039076071957098e-87
# objective function = 5.0
# optimal point is = 4.938294550517956e-87
# objective function = 5.0
# optimal point is = 4.839528659507596e-87
# objective function = 5.0
# optimal point is = 4.742738086317445e-87
# objective function = 5.0
# optimal point is = 4.647883324591096e-87
# objective function = 5.0
# optimal point is = 4.554925658099274e-87
# objective function = 5.0
# optimal point is = 4.463827144937289e-87
# objective function = 5.0
# optimal point is = 4.374550602038543e-87
# objective function = 5.0
# optimal point is = 4.287059589997772e-87
# objective function = 5.0
# optimal point is = 4.2013183981978166e-87
# objective function = 5.0
# optimal point is = 4.1172920302338605e-87
# objective function = 5.0
# optimal point is = 4.034946189629183e-87
# objective function = 5.0
# optimal point is = 3.954247265836599e-87
# objective function = 5.0
# optimal point is = 3.875162320519867e-87
# objective function = 5.0
# optimal point is = 3.7976590741094698e-87
# objective function = 5.0
# optimal point is = 3.7217058926272805e-87
# objective function = 5.0
# optimal point is = 3.647271774774735e-87
# objective function = 5.0
# optimal point is = 3.5743263392792404e-87
# objective function = 5.0
# optimal point is = 3.5028398124936557e-87
# objective function = 5.0
# optimal point is = 3.4327830162437826e-87
# objective function = 5.0
# optimal point is = 3.3641273559189068e-87
# objective function = 5.0
# optimal point is = 3.2968448088005285e-87
# objective function = 5.0
# optimal point is = 3.230907912624518e-87
# objective function = 5.0
# optimal point is = 3.1662897543720276e-87
# objective function = 5.0
# optimal point is = 3.102963959284587e-87
# objective function = 5.0
# optimal point is = 3.040904680098895e-87
# objective function = 5.0
# optimal point is = 2.980086586496917e-87
# objective function = 5.0
# optimal point is = 2.920484854766979e-87
# objective function = 5.0
# optimal point is = 2.8620751576716393e-87
# objective function = 5.0
# optimal point is = 2.8048336545182066e-87
# objective function = 5.0
# optimal point is = 2.7487369814278425e-87
# objective function = 5.0
# optimal point is = 2.6937622417992857e-87
# objective function = 5.0
# optimal point is = 2.6398869969633e-87
# objective function = 5.0
# optimal point is = 2.587089257024034e-87
# objective function = 5.0
# optimal point is = 2.5353474718835534e-87
# objective function = 5.0
# optimal point is = 2.484640522445882e-87
# objective function = 5.0
# optimal point is = 2.4349477119969643e-87
# objective function = 5.0
# optimal point is = 2.386248757757025e-87
# objective function = 5.0
# optimal point is = 2.338523782601885e-87
# objective function = 5.0
# optimal point is = 2.2917533069498473e-87
# objective function = 5.0
# optimal point is = 2.2459182408108505e-87
# objective function = 5.0
# optimal point is = 2.2009998759946333e-87
# objective function = 5.0
# optimal point is = 2.1569798784747404e-87
# objective function = 5.0
# optimal point is = 2.113840280905246e-87
# objective function = 5.0
# optimal point is = 2.0715634752871407e-87
# objective function = 5.0
# optimal point is = 2.030132205781398e-87
# objective function = 5.0
# optimal point is = 1.9895295616657698e-87
# objective function = 5.0
# optimal point is = 1.9497389704324544e-87
# objective function = 5.0
# optimal point is = 1.9107441910238054e-87
# objective function = 5.0
# optimal point is = 1.8725293072033292e-87
# objective function = 5.0
# optimal point is = 1.8350787210592627e-87
# objective function = 5.0
# optimal point is = 1.7983771466380775e-87
# objective function = 5.0
# optimal point is = 1.762409603705316e-87
# objective function = 5.0
# optimal point is = 1.7271614116312096e-87
# objective function = 5.0
